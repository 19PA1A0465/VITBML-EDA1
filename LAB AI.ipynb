# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0465/VITBML-EDA1/blob/master/LAB%20AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # for handling data in the form of tables
import numpy as np # For handling matrix
from sklearn.model_selection import train_test_split # For spliting the data into train and test
from sklearn.linear_model import LinearRegression # for using the model
from sklearn import metrics
# import matplotlib.pyplot as plt # for plotting

# %%
ipl=pd.read_csv("students_placement_data.csv")
ipl
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
ipl.describe()# to study  all stastics summry
# Out:
#           Roll No  SSC Percentage  ...  B.Tech_percentage    Backlogs
# count  117.000000      117.000000  ...         117.000000  117.000000
# mean    59.000000       80.324359  ...          62.943419    4.111111
# std     33.919021        8.879266  ...          12.064306    6.335148
# min      1.000000       47.800000  ...          31.200000    0.000000
# 25%     30.000000       76.000000  ...          54.180000    0.000000
# 50%     59.000000       82.330000  ...          64.360000    0.000000
# 75%     88.000000       87.000000  ...          72.570000    7.000000
# max    117.000000       93.660000  ...          88.100000   25.000000
#
# [8 rows x 5 columns]

# %%
ipl.describe(include="all")# to study  all stastics summry
# Out:
#            Roll No Gender  ... registered_for_ Placement_Training  placement status
# count   117.000000    117  ...                                117               117
# unique         NaN      2  ...                                  2                 2
# top            NaN      M  ...                                yes        Not placed
# freq           NaN     68  ...                                 67                78
# mean     59.000000    NaN  ...                                NaN               NaN
# std      33.919021    NaN  ...                                NaN               NaN
# min       1.000000    NaN  ...                                NaN               NaN
# 25%      30.000000    NaN  ...                                NaN               NaN
# 50%      59.000000    NaN  ...                                NaN               NaN
# 75%      88.000000    NaN  ...                                NaN               NaN
# max     117.000000    NaN  ...                                NaN               NaN
#
# [11 rows x 9 columns]

# %%
ipl.plot(x='SSC Percentage',y='inter_Diploma_percentage',style='*')# to how they are corelated

# %%
#converting a  series into numpy array
x=ipl['SSC Percentage'].values.reshape(-1,1)
x
y=ipl['inter_Diploma_percentage'].values.reshape(-1,1)
y
# Out:
# array([[65.3 ],
#        [92.4 ],
#        [68.  ],
#        [70.4 ],
#        [65.5 ],
#        [68.  ],
#        [56.5 ],
#        [79.3 ],
#        [89.6 ],
#        [75.5 ],
#        [76.3 ],
#        [66.  ],
#        [60.3 ],
#        [88.7 ],
#        [52.2 ],
#        [86.  ],
#        [85.  ],
#        [95.1 ],
#        [86.3 ],
#        [93.6 ],
#        [90.3 ],
#        [83.9 ],
#        [83.  ],
#        [90.4 ],
#        [87.2 ],
#        [78.3 ],
#        [81.  ],
#        [65.3 ],
#        [67.1 ],
#        [88.1 ],
#        [96.5 ],
#        [77.7 ],
#        [88.9 ],
#        [80.1 ],
#        [78.4 ],
#        [90.  ],
#        [91.4 ],
#        [94.3 ],
#        [76.8 ],
#        [88.8 ],
#        [91.4 ],
#        [61.2 ],
#        [67.5 ],
#        [92.5 ],
#        [83.7 ],
#        [84.4 ],
#        [76.9 ],
#        [89.1 ],
#        [77.2 ],
#        [93.8 ],
#        [92.2 ],
#        [79.  ],
#        [73.4 ],
#        [84.5 ],
#        [83.6 ],
#        [92.  ],
#        [56.7 ],
#        [67.8 ],
#        [93.7 ],
#        [94.7 ],
#        [85.6 ],
#        [91.2 ],
#        [76.5 ],
#        [69.2 ],
#        [94.2 ],
#        [91.6 ],
#        [90.4 ],
#        [89.9 ],
#        [61.  ],
#        [52.4 ],
#        [95.6 ],
#        [93.  ],
#        [83.7 ],
#        [80.1 ],
#        [81.7 ],
#        [87.8 ],
#        [59.  ],
#        [91.7 ],
#        [86.  ],
#        [81.  ],
#        [91.9 ],
#        [91.6 ],
#        [90.5 ],
#        [88.9 ],
#        [88.4 ],
#        [83.8 ],
#        [54.2 ],
#        [73.6 ],
#        [77.7 ],
#        [83.  ],
#        [80.2 ],
#        [79.9 ],
#        [89.1 ],
#        [81.  ],
#        [88.6 ],
#        [61.1 ],
#        [96.9 ],
#        [80.4 ],
#        [93.9 ],
#        [84.1 ],
#        [64.2 ],
#        [89.6 ],
#        [93.7 ],
#        [67.9 ],
#        [62.6 ],
#        [73.  ],
#        [69.6 ],
#        [81.01],
#        [70.91],
#        [73.  ],
#        [75.13],
#        [69.  ],
#        [78.6 ],
#        [85.12],
#        [89.9 ],
#        [90.63],
#        [83.33]])

# %%
 #Now divide the data into train and test. Here we are keeping 30% as our test set
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.4)
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
# Out:
# [[90.  ]
#  [81.83]
#  [76.  ]
#  [84.83]
#  [81.1 ]
#  [72.17]
#  [72.  ]
#  [79.33]
#  [87.3 ]
#  [83.5 ]
#  [70.  ]
#  [74.  ]
#  [87.33]
#  [72.5 ]
#  [83.16]
#  [93.66]
#  [89.33]
#  [85.5 ]
#  [76.83]
#  [80.3 ]
#  [71.  ]
#  [77.33]
#  [80.  ]
#  [85.33]
#  [75.5 ]
#  [87.33]
#  [87.83]
#  [88.16]
#  [78.6 ]
#  [74.5 ]
#  [85.  ]
#  [88.  ]
#  [92.66]
#  [92.33]
#  [64.3 ]
#  [87.1 ]
#  [71.  ]
#  [88.3 ]
#  [87.5 ]
#  [82.66]
#  [63.66]
#  [72.  ]
#  [74.5 ]
#  [50.66]
#  [87.33]
#  [90.33]
#  [82.3 ]
#  [47.8 ]
#  [79.83]
#  [62.  ]
#  [84.1 ]
#  [86.  ]
#  [81.  ]
#  [87.1 ]
#  [86.  ]
#  [90.3 ]
#  [90.5 ]
#  [78.  ]
#  [87.33]
#  [85.  ]
#  [64.  ]
#  [82.9 ]
#  [77.5 ]
#  [82.  ]
#  [85.33]
#  [82.83]
#  [88.16]
#  [86.6 ]
#  [81.83]
#  [75.33]]
# [[81.26]
#  [67.  ]
#  [84.84]
#  [83.5 ]
#  [68.16]
#  [60.83]
#  [88.1 ]
#  [90.66]
#  [79.  ]
#  [91.  ]
#  [83.83]
#  [65.3 ]
#  [87.42]
#  [85.5 ]
#  [72.  ]
#  [83.66]
#  [82.  ]
#  [79.  ]
#  [82.3 ]
#  [79.  ]
#  [83.5 ]
#  [86.  ]
#  [79.6 ]
#  [83.  ]
#  [55.66]
#  [83.  ]
#  [63.1 ]
#  [77.16]
#  [81.3 ]
#  [80.66]
#  [81.33]
#  [74.  ]
#  [85.83]
#  [89.  ]
#  [67.  ]
#  [82.33]
#  [89.  ]
#  [66.16]
#  [74.16]
#  [79.9 ]
#  [81.1 ]
#  [91.  ]
#  [86.16]
#  [86.66]
#  [89.  ]
#  [87.  ]
#  [83.66]]
# [[91.6 ]
#  [83.7 ]
#  [80.1 ]
#  [79.3 ]
#  [78.6 ]
#  [77.7 ]
#  [88.1 ]
#  [61.1 ]
#  [65.3 ]
#  [89.9 ]
#  [81.  ]
#  [88.4 ]
#  [83.8 ]
#  [67.8 ]
#  [79.9 ]
#  [95.1 ]
#  [88.6 ]
#  [83.6 ]
#  [80.4 ]
#  [83.  ]
#  [70.4 ]
#  [76.5 ]
#  [83.33]
#  [91.2 ]
#  [81.7 ]
#  [90.  ]
#  [93.6 ]
#  [91.4 ]
#  [87.8 ]
#  [78.3 ]
#  [89.6 ]
#  [67.9 ]
#  [93.7 ]
#  [96.9 ]
#  [67.1 ]
#  [88.7 ]
#  [56.5 ]
#  [93.9 ]
#  [84.4 ]
#  [89.6 ]
#  [69.  ]
#  [81.  ]
#  [69.6 ]
#  [54.2 ]
#  [96.5 ]
#  [95.6 ]
#  [75.13]
#  [52.4 ]
#  [64.2 ]
#  [70.91]
#  [73.  ]
#  [92.5 ]
#  [73.  ]
#  [81.  ]
#  [91.9 ]
#  [93.7 ]
#  [90.4 ]
#  [59.  ]
#  [92.  ]
#  [61.  ]
#  [56.7 ]
#  [73.4 ]
#  [83.9 ]
#  [91.4 ]
#  [93.8 ]
#  [84.1 ]
#  [80.1 ]
#  [78.4 ]
#  [85.6 ]
#  [61.2 ]]
# [[68.  ]
#  [68.  ]
#  [91.6 ]
#  [88.8 ]
#  [62.6 ]
#  [80.2 ]
#  [89.1 ]
#  [94.7 ]
#  [79.  ]
#  [94.3 ]
#  [90.3 ]
#  [77.7 ]
#  [92.2 ]
#  [90.63]
#  [84.5 ]
#  [90.4 ]
#  [73.6 ]
#  [93.  ]
#  [83.7 ]
#  [88.9 ]
#  [76.9 ]
#  [94.2 ]
#  [69.2 ]
#  [81.01]
#  [65.3 ]
#  [83.  ]
#  [52.2 ]
#  [89.1 ]
#  [85.12]
#  [86.3 ]
#  [60.3 ]
#  [76.8 ]
#  [86.  ]
#  [92.4 ]
#  [65.5 ]
#  [76.3 ]
#  [88.9 ]
#  [77.2 ]
#  [91.7 ]
#  [75.5 ]
#  [67.5 ]
#  [66.  ]
#  [87.2 ]
#  [89.9 ]
#  [86.  ]
#  [85.  ]
#  [90.5 ]]

# %%
# Now apply linear regression model on training dataset
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# to find the intercept of our model we use  intercept_
print("intercept=",model.intercept_)
# Out:
# intercept= [10.43304251]

# %%
# To find  slope of our model we use coef_
print("slope=",model.coef_)
# Out:
# slope= [[0.86811766]]

# %%
#a=predict interpercentage
a=model.predict(X_test) 
a
# Out:
# array([[80.97628323],
#        [68.59692546],
#        [84.08414444],
#        [82.92086678],
#        [69.60394194],
#        [63.24063952],
#        [86.914208  ],
#        [89.1365892 ],
#        [79.01433733],
#        [89.4317492 ],
#        [83.20734561],
#        [67.12112544],
#        [86.32388799],
#        [84.65710209],
#        [72.93751374],
#        [83.05976561],
#        [81.6186903 ],
#        [79.01433733],
#        [81.8791256 ],
#        [79.01433733],
#        [82.92086678],
#        [85.09116092],
#        [79.53520792],
#        [82.48680795],
#        [58.75247124],
#        [82.48680795],
#        [65.2112666 ],
#        [77.41700084],
#        [81.01100794],
#        [80.45541264],
#        [81.03705147],
#        [74.67374905],
#        [84.94358092],
#        [87.69551389],
#        [68.59692546],
#        [81.90516913],
#        [87.69551389],
#        [67.86770663],
#        [74.81264788],
#        [79.79564322],
#        [80.83738441],
#        [89.4317492 ],
#        [85.23005975],
#        [85.66411858],
#        [87.69551389],
#        [85.95927858],
#        [83.05976561]])

# %%
# b=actual prediction
b=pd.DataFrame({'predicted':a.flatten(), 'Actual':Y_test.flatten()})
b
# Out:
#     predicted  Actual
# 0   80.976283   68.00
# 1   68.596925   68.00
# 2   84.084144   91.60
# 3   82.920867   88.80
# 4   69.603942   62.60
# 5   63.240640   80.20
# 6   86.914208   89.10
# 7   89.136589   94.70
# 8   79.014337   79.00
# 9   89.431749   94.30
# 10  83.207346   90.30
# 11  67.121125   77.70
# 12  86.323888   92.20
# 13  84.657102   90.63
# 14  72.937514   84.50
# 15  83.059766   90.40
# 16  81.618690   73.60
# 17  79.014337   93.00
# 18  81.879126   83.70
# 19  79.014337   88.90
# 20  82.920867   76.90
# 21  85.091161   94.20
# 22  79.535208   69.20
# 23  82.486808   81.01
# 24  58.752471   65.30
# 25  82.486808   83.00
# 26  65.211267   52.20
# 27  77.417001   89.10
# 28  81.011008   85.12
# 29  80.455413   86.30
# 30  81.037051   60.30
# 31  74.673749   76.80
# 32  84.943581   86.00
# 33  87.695514   92.40
# 34  68.596925   65.50
# 35  81.905169   76.30
# 36  87.695514   88.90
# 37  67.867707   77.20
# 38  74.812648   91.70
# 39  79.795643   75.50
# 40  80.837384   67.50
# 41  89.431749   66.00
# 42  85.230060   87.20
# 43  85.664119   89.90
# 44  87.695514   86.00
# 45  85.959279   85.00
# 46  83.059766   90.50

# %%
import matplotlib.pyplot as plt
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_test,a)

# %%
print('R2 error:',metrics.r2_score(Y_test, a))
# Out:
# R2 error: 0.27941414879617976
