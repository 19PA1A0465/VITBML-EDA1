# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0465/VITBML-EDA1/blob/master/MBA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **17k mobile strategy game analysis data**

# %% [markdown]
# **game means games data imported from kaggle.com/datasets**

# %% [markdown]
# **pd-this vaiable s imported for pandas package....other keywords are dedescribed in the cells......**

# %% [markdown]
# ##1.what is the datatype of game dataset?
# ##2.what is the size of gamedata?
# ##3.what is the dimensions of given dataset?
# ##4.Top 18 rows of given dataset?
# ##5.what are the features of rows in dataset

# %% [markdown]
# # **PANDAS DATAFRAME**

# %%
#import pandas
import pandas as pd

# %% [markdown]
# ## **Reading data**

# %%
#read data from csv file
game=pd.read_csv('appstore_games.csv')

# %%
print(game)
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %% [markdown]
# # **Checking data dimensions**

# %% [markdown]
# **use the shape method to get the dimensions**

# %%
print(game.shape)
# Out:
# (17007, 18)

# %% [markdown]
# # **DATA INSPECTION**

# %%
#To see last 8 rows we use tail method
game.tail(8)
# Out:
#                                                      URL  ...  Current Version Release Date
# 16999  https://apps.apple.com/us/app/number-puzzle-20...  ...                     7/30/2019
# 17000  https://apps.apple.com/us/app/super-kid/id1474...  ...                     8/16/2019
# 17001  https://apps.apple.com/us/app/lava-island-adve...  ...                     8/31/2019
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  ...                      8/1/2019
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  ...                      8/2/2019
#
# [8 rows x 18 columns]

# %%
##To GETTING TOP 8 ROWS OF DATA USING head method
game.head(8)
# Out:
#                                                  URL  ...  Current Version Release Date
# 0   https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1  https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2  https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# 5  https://apps.apple.com/us/app/sudoku-classic-n...  ...                     4/29/2019
# 6  https://apps.apple.com/us/app/gravitation/id28...  ...                    11/14/2013
# 7   https://apps.apple.com/us/app/colony/id286363959  ...                     10/3/2018
#
# [8 rows x 18 columns]

# %%
##.columns gives column names of given data sets
print(game.columns)
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %% [markdown]
# # **1.DATA TYPES**

# %%
# .dtypes gives data types of each column.......
print(game.dtypes)
# Out:
# URL                              object
# ID                                int64
# Name                             object
# Subtitle                         object
# Icon URL                         object
# Average User Rating             float64
# User Rating Count               float64
# Price                           float64
# In-app Purchases                 object
# Description                      object
# Developer                        object
# Age Rating                       object
# Languages                        object
# Size                            float64
# Primary Genre                    object
# Genres                           object
# Original Release Date            object
# Current Version Release Date     object
# dtype: object

# %% [markdown]
# # **2.CENTRAL TENDENCY**

# %% [markdown]
# # **sorting**

# %%
#sorting data
sorted(game)
game
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %%
type(game)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # **median**

# %%
#To find the median of dataset we use median()
game.median()
# Out:
# ID                     1.112286e+09
# Average User Rating    4.500000e+00
# User Rating Count      4.600000e+01
# Price                  0.000000e+00
# Size                   5.676895e+07
# dtype: float64

# %% [markdown]
# ## **mode**

# %%
#To find the mode we use dataset we use mode()
game.mode()
# Out:
#                                                    URL  ...  Current Version Release Date
# 0    https://apps.apple.com/us/app/10-in-1-board-ga...  ...                      8/1/2019
# 1    https://apps.apple.com/us/app/2048-number-worl...  ...                           NaN
# 2    https://apps.apple.com/us/app/2048-pirates-tre...  ...                           NaN
# 3    https://apps.apple.com/us/app/addit-number-gam...  ...                           NaN
# 4    https://apps.apple.com/us/app/additions/id1432...  ...                           NaN
# ..                                                 ...  ...                           ...
# 155   https://apps.apple.com/us/app/yessir/id771609442  ...                           NaN
# 156  https://apps.apple.com/us/app/zombie-ground-io...  ...                           NaN
# 157  https://apps.apple.com/us/app/zombie-gunner-de...  ...                           NaN
# ...

# %% [markdown]
# # **Mean**

# %%
#mean for axis=1
game.mean(axis=1)
# Out:
# 0        6.015571e+07
# 1        5.945113e+07
# 2        5.712596e+07
# 3        6.149960e+07
# 4        6.410406e+07
#              ...
# 17002    5.131407e+08
# 17003    5.284201e+08
# 17004    4.993901e+08
# 17005    5.572380e+08
# 17006    4.993432e+08
# Length: 17007, dtype: float64

# %% [markdown]
# # **3.VARIABILITY**

# %%
# standard deviation
# degree of freedom = 0
# divided by n instead of divided by n - 1
game.std(ddof=0)
# Out:
# ID                     2.999588e+08
# Average User Rating    7.513778e-01
# User Rating Count      4.231976e+04
# Price                  7.835501e+00
# Size                   2.036417e+08
# dtype: float64

# %%
# to stuby statastic summry in dataset we use  discribe()
game.describe()
# Out:
#                  ID  Average User Rating  ...         Price          Size
# count  1.700700e+04          7561.000000  ...  16983.000000  1.700600e+04
# mean   1.059614e+09             4.060905  ...      0.813419  1.157064e+08
# std    2.999676e+08             0.751428  ...      7.835732  2.036477e+08
# min    2.849214e+08             1.000000  ...      0.000000  5.132800e+04
# 25%    8.996543e+08             3.500000  ...      0.000000  2.295014e+07
# 50%    1.112286e+09             4.500000  ...      0.000000  5.676895e+07
# 75%    1.286983e+09             4.500000  ...      0.000000  1.330271e+08
# max    1.475077e+09             5.000000  ...    179.990000  4.005591e+09
#
# [8 rows x 5 columns]

# %%
# to see all possible statastic summery for all features in dataset we use discribe(include="all")
game.describe(include="all")
# Out:
#                                                       URL  ...  Current Version Release Date
# count                                               17007  ...                         17007
# unique                                              16847  ...                          2512
# top     https://apps.apple.com/us/app/run-an-empire/id...  ...                      8/1/2019
# freq                                                    2  ...                           118
# mean                                                  NaN  ...                           NaN
# std                                                   NaN  ...                           NaN
# min                                                   NaN  ...                           NaN
# 25%                                                   NaN  ...                           NaN
# 50%                                                   NaN  ...                           NaN
# ...

# %% [markdown]
# # **sum**

# %%
#To find the sum of features we use sum()
game.sum()
# Out:
# URL                             https://apps.apple.com/us/app/sudoku/id2849214...
# ID                                                                 18020852159404
# Name                            SudokuReversiMoroccoSudoku (Free)Senet DeluxeS...
# Icon URL                        https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                       30704.5
# User Rating Count                                                     2.50007e+07
# Price                                                                     13814.3
# Description                     Join over 21,000,000 of our fans and download ...
# Developer                       Mighty Mighty Good GamesKiss The MachineBayou ...
# Age Rating                      4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+9+4+...
# Size                                                                   1.9677e+12
# ...

# %% [markdown]
# # **4.About the distribution**

# %%
# Handiling missing values (Dealing with NA)
#Find for NA's
game.isna() # to find for NA's in a dataf
# Out:
#          URL     ID  ...  Original Release Date  Current Version Release Date
# 0      False  False  ...                  False                         False
# 1      False  False  ...                  False                         False
# 2      False  False  ...                  False                         False
# 3      False  False  ...                  False                         False
# 4      False  False  ...                  False                         False
# ...      ...    ...  ...                    ...                           ...
# 17002  False  False  ...                  False                         False
# 17003  False  False  ...                  False                         False
# 17004  False  False  ...                  False                         False
# 17005  False  False  ...                  False                         False
# 17006  False  False  ...                  False                         False
#
# [17007 rows x 18 columns]

# %%
#Fill NA's with zero in dataset
game.fillna(0)
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %%
#Fill NA's with previous value in data set
game.fillna(method='pad')
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %%
#Fill NA's with next values in dataset

game.fillna(method ='bfill')
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %%
#Fill NA's with a constant/text 
game.fillna("Not available",inplace=True) # Note: this will modify any other views on this object
game
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %%
#Use interpolate function to fill the missing values which are in data set
game.interpolate(method="linear") #‘linear’: ignore the index and treat the values as equally spaced. default
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %%
#Remove rows with NA's in dataset
game.dropna() # Drop rows with NA
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %%
#Remove row which contains all NA's

game.dropna(how="all") # Drop the rows containing all NA's
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %%
#Remove the columns containing NA's
game.dropna(axis=1) # drop columns with NA's
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %%
pd.DataFrame(game)
# Out:
#                                                      URL  ...  Current Version Release Date
# 0       https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1      https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2      https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3      https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# ...                                                  ...  ...                           ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  ...                     7/30/2019
# 17003  https://apps.apple.com/us/app/eachother/id1474...  ...                      8/1/2019
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  ...                      8/3/2019
# ...

# %% [markdown]
# # **grouping** **the** **data**

# %%
game.groupby(by='ID').groups
# Out:
# {284921427: Int64Index([0], dtype='int64'),
#  284926400: Int64Index([1], dtype='int64'),
#  284946595: Int64Index([2], dtype='int64'),
#  285755462: Int64Index([3], dtype='int64'),
#  285831220: Int64Index([4], dtype='int64'),
#  286210009: Int64Index([5], dtype='int64'),
#  286313771: Int64Index([6], dtype='int64'),
#  286363959: Int64Index([7], dtype='int64'),
#  286566987: Int64Index([8], dtype='int64'),
#  286682679: Int64Index([9], dtype='int64'),
#  287563734: Int64Index([10], dtype='int64'),
#  288096268: Int64Index([11], dtype='int64'),
#  288669794: Int64Index([12], dtype='int64'),
#  288689440: Int64Index([13], dtype='int64'),
#  288918962: Int64Index([14], dtype='int64'),
#  289217958: Int64Index([15, 16], dtype='int64'),
#  289382458: Int64Index([17], dtype='int64'),
#  290493286: Int64Index([18], dtype='int64'),
#  290614255: Int64Index([19], dtype='int64'),
#  291074572: Int64Index([20], dtype='int64'),
#  291723451: Int64Index([21], dtype='int64'),
# ...

# %% [markdown]
# **graphical** **represetation**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
m=game.head(8)
m.plot(kind="bar")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
n=game.head(18)
n.plot(kind="hist")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np 
m=game["Size"]
n=game["Price"]
plt.scatter(m,n,c="green")

# %% [markdown]
# ## ***correlation***

# %% [markdown]
# ##**Correlation** **desricbes** **the**...
# ##**In** **the** **heat** **map** **the** **url** **and** **icon** **url** **are** **related**..
# ##**In** **the** **heat** **map** **the** **average** **users** **and** **user** **rating** **too**...
# ##**Heat** **map** **are** **highly** **realted** **to** **the** **ID**
#
#
# ---
#
#
#
# ---

# %%
# To find the corelation in data set we use corr()
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
corrMatrix=game.corr()
corrMatrix
# Out:
#                            ID  Average User Rating  ...     Price      Size
# ID                   1.000000             0.210280  ... -0.004187  0.143711
# Average User Rating  0.210280             1.000000  ... -0.000414  0.061617
# User Rating Count   -0.033052             0.033025  ... -0.011149  0.037736
# Price               -0.004187            -0.000414  ...  1.000000  0.033502
# Size                 0.143711             0.061617  ...  0.033502  1.000000
#
# [5 rows x 5 columns]

# %%
#heat graph of corelation values in of data set
import seaborn as sns
sns.heatmap(corrMatrix,annot=True)

# %% [markdown]
# for the above heatgap the corelations we found are
#   1.Here

# %% [markdown]
# # **outlier**

# %%
import seaborn as sns
sns.boxplot(x=game['ID'])
#th outlayers are represented as below

# %% [markdown]
# ## **conclusion**

# %% [markdown]
# from this dataset set analysis we come to know about gaming apps which was released from last 10 years in the data frame we are going to come across features like {'**URL**', '**ID**', '**Name**', '**Subtitle**', '**Icon URL**', '**Average** **User** **Rating** ',
#        '**User** **Rating** **Count**', '**Price**', '**In**-**app** **Purchase ', 'Description',
#        '**Developer**', 'Age **Rating**', '**Languages**', '**Size**' , '**Primary** **Genre**',
#         '**Genres**', '**Original** **Release** **Date**', '**Current** **Version** **Release** **Date**}
#         from this features we can complete analysis the game becase dataset has user ratings, developer id , discription .we can easily see weather to install this app or not
#
#       1.Most of the people liking actions game
#
#       2.IN the data set most ratings were given to action gener games
#       after that board entertinement games
#
#       3.soo many people liking to play action games which was played in online with friends
#
#       4.soo when we want to prepare a gaming app we should concentrate on   action and enterinement  in order to make success

# %% [markdown]
# **bold text**

# %%
# 1question answer
print(game.dtypes)
# Out:
# URL                              object
# ID                                int64
# Name                             object
# Subtitle                         object
# Icon URL                         object
# Average User Rating             float64
# User Rating Count               float64
# Price                           float64
# In-app Purchases                 object
# Description                      object
# Developer                        object
# Age Rating                       object
# Languages                        object
# Size                            float64
# Primary Genre                    object
# Genres                           object
# Original Release Date            object
# Current Version Release Date     object
# dtype: object

# %%
#2question answer
a=game.size
a
# Out:
# 306126

# %%
#3 question answer
a=game.ndim
a
# Out:
# 2

# %%
#4 question answer
game.head(18)
# Out:
#                                                   URL  ...  Current Version Release Date
# 0    https://apps.apple.com/us/app/sudoku/id284921427  ...                     5/30/2017
# 1   https://apps.apple.com/us/app/reversi/id284926400  ...                     5/17/2018
# 2   https://apps.apple.com/us/app/morocco/id284946595  ...                      9/5/2017
# 3   https://apps.apple.com/us/app/sudoku-free/id28...  ...                     5/30/2017
# 4   https://apps.apple.com/us/app/senet-deluxe/id2...  ...                     7/22/2018
# 5   https://apps.apple.com/us/app/sudoku-classic-n...  ...                     4/29/2019
# 6   https://apps.apple.com/us/app/gravitation/id28...  ...                    11/14/2013
# 7    https://apps.apple.com/us/app/colony/id286363959  ...                     10/3/2018
# 8     https://apps.apple.com/us/app/carte/id286566987  ...                    11/23/2017
# ...

# %%
#5 question answer
game.axes
# Out:
# [RangeIndex(start=0, stop=17007, step=1),
#  Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#         'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#         'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#         'Genres', 'Original Release Date', 'Current Version Release Date'],
#        dtype='object')]
